# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset_Facebook.csv', sep=';')

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
data['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
data_photo = data[data["Type"] == "Photo"]
data_photo.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
data_status = data[data["Type"] == "Status"]
data_status.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_video = data[data["Type"] == "Video"]
data_video.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_link = data[data["Type"] == "Link"]
data_link.head()
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_merged = pd.concat([data_photo, data_status])
data_merged
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 334            119198  Status         2           5             1          2
# 352            116435  Status         1           5             4          3
# 362            116091  Status         2           5             5          7
# 371            113028  Status         2           4             6          3
# 416            104070  Status         1           3             3         15
#
# ...

# %%
print('Photo subset shape : ')
data_photo.shape
# Out:
# Photo subset shape :
# (426, 19)

# %%
print('Status subset shape : ')
data_status.shape
# Out:
# Status subset shape :
# (45, 19)

# %%
print('Merged subset shape : ')
data_merged.shape
# Out:
# Merged subset shape :
# (471, 19)

# %% [markdown]
# ## **Sorting data on Page total likes**

# %%
data_sort_like = data.sort_values(by=["like"], ascending=False)
data_sort_like.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 379   1.0                     105632                           147918
# 349   0.0                      81856                           124753
# 168   0.0                      41984                            68290
# 3     1.0                      50128                            87991
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_sort_comments = data.sort_values(by=['comment'], ascending=False)
data_sort_comments.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 460   0.0                      55520                           665792
# 168   0.0                      41984                            68290
# 288   0.0                      20896                            29062
# 228   0.0                      14824                            21863
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data_sort_shares = data.sort_values(by=['share'], ascending=False)
data_sort_shares.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 168            135428  Photo         1           9             3         10
# 460             92507  Photo         3           2             1         13
# 3              139441  Photo         2          12             2         10
# 105            137020  Photo         1          10             2          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 168   0.0                      41984                            68290
# 460   0.0                      55520                           665792
# 3     1.0                      50128                            87991
# 105   0.0                      70144                           111745
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## **Transposing Data**

# %%
data_transpose = data.transpose()
data_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# ## **Shape and Reshape Data**

# %%
data['index'] = range(1, len(data) + 1)
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## **Melting Data to Long Format**

# %%
data_melted = pd.melt(data, id_vars=['Type', 'Category'], var_name='Metrics')
data_melted
# Out:
#         Type  Category           Metrics     value
# 0      Photo         2  Page total likes  139441.0
# 1     Status         2  Page total likes  139441.0
# 2      Photo         3  Page total likes  139441.0
# 3      Photo         2  Page total likes  139441.0
# 4      Photo         2  Page total likes  139441.0
# ...      ...       ...               ...       ...
# 8995   Photo         3             index     496.0
# 8996   Photo         2             index     497.0
# 8997   Photo         1             index     498.0
# 8998   Photo         3             index     499.0
# 8999   Photo         2             index     500.0
#
# [9000 rows x 4 columns]

# %%
# melting the data using10g melt()

data_melted = pd.melt(data, id_vars='index', var_name='Total Interactions')
data_melted
# Out:
#       index  Total Interactions   value
# 0         1    Page total likes  139441
# 1         2    Page total likes  139441
# 2         3    Page total likes  139441
# 3         4    Page total likes  139441
# 4         5    Page total likes  139441
# ...     ...                 ...     ...
# 9495    496  Total Interactions      84
# 9496    497  Total Interactions      75
# 9497    498  Total Interactions     115
# 9498    499  Total Interactions     136
# 9499    500  Total Interactions     119
#
# [9500 rows x 3 columns]

# %%
# melting the data using melt()
data_melted = pd.melt(data, id_vars='index', var_name='Type')
data_melted
# Out:
#       index                Type   value
# 0         1    Page total likes  139441
# 1         2    Page total likes  139441
# 2         3    Page total likes  139441
# 3         4    Page total likes  139441
# 4         5    Page total likes  139441
# ...     ...                 ...     ...
# 9495    496  Total Interactions      84
# 9496    497  Total Interactions      75
# 9497    498  Total Interactions     115
# 9498    499  Total Interactions     136
# 9499    500  Total Interactions     119
#
# [9500 rows x 3 columns]

# %% [markdown]
# ## **Casting data to wide format**

# %%
casting = pd.pivot_table(data, index=['Type', 'Category'], values='like', fill_value = 0)
casting.head()
# Out:
#                       like
# Type  Category
# Link  1          75.650000
#       2          32.000000
#       3          68.000000
# Photo 1         126.000000
#       2         235.857143
